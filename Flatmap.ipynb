# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# %matplotlib notebook

# %%
x=np.loadtxt('rotational.txt')
y=np.loadtxt('radial.txt')
curv=np.loadtxt('icbm_avg_mid_sym_mc_atlas_left.txt')

# %%
plt.figure(figsize=[6,6])

plt.scatter(x,y,color=cm.spectral(curv/np.max(curv).astype(float)),s=0.1)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
curv
# Out:
# array([ 6.,  7.,  3., ...,  7.,  7.,  7.])
